# %% [markdown]
# ## TF-idf Implementation

# %%
import pandas as pd 
messages=pd.read_csv('spamCollection.csv',     
                    sep=',',names=["label","message"])

# %%
messages
# Out:
#     label                                            message
# 0   label                                            message
# 1     ham                 Hey there how are you doing today?
# 2    spam  Congratulations you have won a 1000 dollar Wal...
# 3     ham           Are we still meeting for dinner tonight?
# 4    spam  URGENT your account has been compromised verif...
# ..    ...                                                ...
# 80   spam       Click here to unlock your free bonus credits
# 81    ham                             Let's meet at the cafe
# 82   spam    Exclusive offer for you limited stock available
# 83    ham                           Okay I will check it out
# 84   spam   You have an unread important message tap to open
#
# [85 rows x 2 columns]

# %%
import re     
import nltk   
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer  
wordlemmatize=WordNetLemmatizer()

# %%
corpus=[]           
for i in range(0,len(messages)):           
    review=re.sub('[^a-zA-z]',' ',messages['message'][i])
    review=review.lower()    
    review=review.split()                           
    review=[wordlemmatize.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)    
    corpus.append(review)

# %%
corpus
# Out:
# ['message',
#  'hey today',
#  'congratulation dollar walmart gift card click claim',
#  'still meeting dinner tonight',
#  'urgent account compromised verify immediately',
#  'ill call reach home',
#  'get cheap loan low interest apply instantly',
#  'send assignment note please',
#  'selected free vacation call claim',
#  'let catch tomorrow class',
#  'win brand new iphone answering three question',
#  'happy birthday hope great day',
#  'last chance claim free reward act',
#  'forget bring notebook tomorrow',
#  'chosen receive complimentary credit score check',
#  'thanks help earlier',
#  'free entry weekly competition win ticket bahamas',
#  'reschedule meeting pm',
#  'pre approved credit card apply',
#  'good night see tomorrow',
#  'exclusive deal seventy percent item limited time',
#  'right',
#  'claim free movie ticket reply yes',
#  'finish work tonight',
#  'mobile number awarded cash prize',
#  'meet library ten minute',
#  'selected cash back reward offer',
#  'reached safely talk later',
#  'limited time offer buy one get one free',
#  'please send file free',
#  'loan request approved contact u immediately',
#  'let know arrive',
#  'activate free membership',
#  'want join u lunch',
#  'winner selected lucky draw',
#  'get back meeting',
#  'click link secure free gift',
#  'everything fine checking',
#  'atm card blocked verify',
#  'woke plan today',
#  'important update account need verification',
#  'okay see soon',
#  'selected exclusive offer valid today',
#  'call ten minute',
#  'email cash prize worth dollar',
#  'send location',
#  'subscription expired renew continue',
#  'thank update',
#  'claim discount voucher midnight',
#  'talk later',
#  'chosen free shopping voucher',
#  'meeting postponed tomorrow morning',
#  'number shortlisted lottery prize',
#  'please check message',
#  'earn money home investment required start',
#  'time coming',
#  'free recharge reply claim',
#  'let study together today',
#  'account login detected different device verify',
#  'call later',
#  'selected holiday package zero cost',
#  'reach five minute',
#  'congratulation selected exclusive vip offer',
#  'forget submit assignment',
#  'free trial activated cancel anytime',
#  'emailed file',
#  'phone selected upgrade offer',
#  'complete project',
#  'get free health checkup voucher',
#  'see soon take care',
#  'congratulation number lucky prize',
#  'call done',
#  'verify identity avoid deactivation',
#  'late today',
#  'special discount available grab',
#  'send detail please',
#  'reward waiting click collect',
#  'talk later',
#  'account suspended hour verify immediately',
#  'thank calling back',
#  'click unlock free bonus credit',
#  'let meet cafe',
#  'exclusive offer limited stock available',
#  'okay check',
#  'unread important message tap open']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(max_features=100)  
X=tfidf.fit_transform(corpus).toarray()

# %%
import numpy as np
np.set_printoptions(edgeitems=30, linewidth=100000, 
    formatter=dict(float=lambda x: "%.3g" % x))

# %%
tfidf=TfidfVectorizer(max_features=100,ngram_range=(1,2))
X=tfidf.fit_transform(corpus).toarray()

# %%
tfidf.vocabulary_
# Out:
# {'message': np.int64(52),
#  'today': np.int64(76),
#  'congratulation': np.int64(30),
#  'dollar': np.int64(33),
#  'walmart': np.int64(86),
#  'gift': np.int64(40),
#  'card': np.int64(20),
#  'click': np.int64(27),
#  'claim': np.int64(25),
#  'walmart gift': np.int64(87),
#  'meeting': np.int64(51),
#  'tonight': np.int64(78),
#  'account': np.int64(0),
#  'compromised': np.int64(28),
#  'verify': np.int64(80),
#  'immediately': np.int64(42),
#  'compromised verify': np.int64(29),
#  'verify immediately': np.int64(81),
#  'call': np.int64(19),
#  'reach': np.int64(60),
#  'home': np.int64(41),
#  'get': np.int64(39),
#  'loan': np.int64(48),
#  'apply': np.int64(12),
#  'apply instantly': np.int64(13),
#  'send': np.int64(67),
#  'assignment': np.int64(16),
#  'please': np.int64(58),
#  'selected': np.int64(65),
#  'free': np.int64(38),
#  'let': np.int64(45),
#  'tomorrow': np.int64(77),
#  'win': np.int64(92),
#  'answering': np.int64(9),
#  'win brand': np.int64(93),
#  'answering three': np.int64(10),
#  'reward': np.int64(62),
#  'act': np.int64(4),
#  'claim free': np.int64(26),
#  'forget': np.int64(37),
#  'chosen': np.int64(24),
#  'credit': np.int64(31),
#  'check': np.int64(23),
#  'weekly': np.int64(90),
#  'ticket': np.int64(74),
#  'weekly competition': np.int64(91),
#  'win ticket': np.int64(94),
#  'approved': np.int64(14),
#  'see': np.int64(63),
#  'exclusive': np.int64(34),
#  'limited': np.int64(46),
#  'time': np.int64(75),
#  'limited time': np.int64(47),
#  'reply': np.int64(61),
#  'work': np.int64(99),
#  'number': np.int64(54),
#  'cash': np.int64(21),
#  'prize': np.int64(59),
#  'cash prize': np.int64(22),
#  'meet': np.int64(50),
#  'ten': np.int64(71),
#  'minute': np.int64(53),
#  'ten minute': np.int64(72),
#  'back': np.int64(18),
#  'offer': np.int64(55),
#  'talk': np.int64(69),
#  'later': np.int64(44),
#  'talk later': np.int64(70),
#  'one': np.int64(57),
#  'file': np.int64(36),
#  'approved contact': np.int64(15),
#  'activate': np.int64(5),
#  'activate free': np.int64(6),
#  'want': np.int64(88),
#  'want join': np.int64(89),
#  'winner': np.int64(95),
#  'lucky': np.int64(49),
#  'winner selected': np.int64(96),
#  'woke': np.int64(97),
#  'woke plan': np.int64(98),
#  'important': np.int64(43),
#  'update': np.int64(79),
#  'account need': np.int64(2),
#  'okay': np.int64(56),
#  'soon': np.int64(68),
#  'see soon': np.int64(64),
#  'selected exclusive': np.int64(66),
#  'exclusive offer': np.int64(35),
#  'thank': np.int64(73),
#  'discount': np.int64(32),
#  'voucher': np.int64(82),
#  'voucher midnight': np.int64(83),
#  'account login': np.int64(1),
#  'activated': np.int64(7),
#  'anytime': np.int64(11),
#  'activated cancel': np.int64(8),
#  'available': np.int64(17),
#  'waiting': np.int64(84),
#  'waiting click': np.int64(85),
#  'account suspended': np.int64(3)}

# %%
X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X
#
# NameError: name 'X' is not defined
