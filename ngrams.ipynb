# %% [markdown]
# ## N-Grams Implementation

# %%
import pandas as pd
messages=pd.read_csv('spamCollection.csv',
                    sep=',',names=["label","message"])

# %%
messages
# Out:
#     label                                            message
# 0   label                                            message
# 1     ham                 Hey there how are you doing today?
# 2    spam  Congratulations you have won a 1000 dollar Wal...
# 3     ham           Are we still meeting for dinner tonight?
# 4    spam  URGENT your account has been compromised verif...
# ..    ...                                                ...
# 80   spam       Click here to unlock your free bonus credits
# 81    ham                             Let's meet at the cafe
# 82   spam    Exclusive offer for you limited stock available
# 83    ham                           Okay I will check it out
# 84   spam   You have an unread important message tap to open
#
# [85 rows x 2 columns]

# %%
import re   
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer   
ps=PorterStemmer()

# %%
corpus=[]
for i in range(0,len(messages)):    
    review=re.sub('[^a-zA-z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()     
    review=[ps.stem(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)   
    corpus.append(review)

# %%
corpus
# Out:
# ['messag',
#  'hey today',
#  'congratul dollar walmart gift card click claim',
#  'still meet dinner tonight',
#  'urgent account compromis verifi immedi',
#  'ill call reach home',
#  'get cheap loan low interest appli instantli',
#  'send assign note pleas',
#  'select free vacat call claim',
#  'let catch tomorrow class',
#  'win brand new iphon answer three question',
#  'happi birthday hope great day',
#  'last chanc claim free reward act',
#  'forget bring notebook tomorrow',
#  'chosen receiv complimentari credit score check',
#  'thank help earlier',
#  'free entri weekli competit win ticket bahama',
#  'reschedul meet pm',
#  'pre approv credit card appli',
#  'good night see tomorrow',
#  'exclus deal seventi percent item limit time',
#  'right',
#  'claim free movi ticket repli ye',
#  'finish work tonight',
#  'mobil number award cash prize',
#  'meet librari ten minut',
#  'select cash back reward offer',
#  'reach safe talk later',
#  'limit time offer buy one get one free',
#  'pleas send file free',
#  'loan request approv contact us immedi',
#  'let know arriv',
#  'activ free membership',
#  'want join us lunch',
#  'winner select lucki draw',
#  'get back meet',
#  'click link secur free gift',
#  'everyth fine check',
#  'atm card block verifi',
#  'woke plan today',
#  'import updat account need verif',
#  'okay see soon',
#  'select exclus offer valid today',
#  'call ten minut',
#  'email cash prize worth dollar',
#  'send locat',
#  'subscript expir renew continu',
#  'thank updat',
#  'claim discount voucher midnight',
#  'talk later',
#  'chosen free shop voucher',
#  'meet postpon tomorrow morn',
#  'number shortlist lotteri prize',
#  'pleas check messag',
#  'earn money home invest requir start',
#  'time come',
#  'free recharg repli claim',
#  'let studi togeth today',
#  'account login detect differ devic verifi',
#  'call later',
#  'select holiday packag zero cost',
#  'reach five minut',
#  'congratul select exclus vip offer',
#  'forget submit assign',
#  'free trial activ cancel anytim',
#  'email file',
#  'phone select upgrad offer',
#  'complet project',
#  'get free health checkup voucher',
#  'see soon take care',
#  'congratul number lucki prize',
#  'call done',
#  'verifi ident avoid deactiv',
#  'late today',
#  'special discount avail grab',
#  'send detail pleas',
#  'reward wait click collect',
#  'talk later',
#  'account suspend hour verifi immedi',
#  'thank call back',
#  'click unlock free bonu credit',
#  'let meet cafe',
#  'exclus offer limit stock avail',
#  'okay check',
#  'unread import messag tap open']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=100,binary=True)

# %%
X=cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'messag': np.int64(73),
#  'today': np.int64(92),
#  'congratul': np.int64(20),
#  'dollar': np.int64(34),
#  'gift': np.int64(51),
#  'card': np.int64(8),
#  'click': np.int64(15),
#  'claim': np.int64(13),
#  'meet': np.int64(72),
#  'dinner': np.int64(32),
#  'tonight': np.int64(94),
#  'account': np.int64(0),
#  'verifi': np.int64(97),
#  'immedi': np.int64(61),
#  'call': np.int64(7),
#  'reach': np.int64(80),
#  'home': np.int64(59),
#  'get': np.int64(50),
#  'loan': np.int64(70),
#  'appli': np.int64(2),
#  'send': np.int64(85),
#  'assign': np.int64(4),
#  'pleas': np.int64(78),
#  'select': np.int64(84),
#  'free': np.int64(49),
#  'let': np.int64(68),
#  'catch': np.int64(10),
#  'tomorrow': np.int64(93),
#  'class': np.int64(14),
#  'win': np.int64(99),
#  'iphon': np.int64(63),
#  'happi': np.int64(55),
#  'hope': np.int64(60),
#  'great': np.int64(54),
#  'day': np.int64(25),
#  'reward': np.int64(82),
#  'forget': np.int64(48),
#  'chosen': np.int64(12),
#  'credit': np.int64(24),
#  'check': np.int64(11),
#  'thank': np.int64(89),
#  'help': np.int64(57),
#  'earlier': np.int64(37),
#  'entri': np.int64(40),
#  'competit': np.int64(18),
#  'ticket': np.int64(90),
#  'approv': np.int64(3),
#  'good': np.int64(52),
#  'see': np.int64(83),
#  'exclus': np.int64(42),
#  'deal': np.int64(27),
#  'item': np.int64(64),
#  'limit': np.int64(69),
#  'time': np.int64(91),
#  'repli': np.int64(81),
#  'finish': np.int64(46),
#  'number': np.int64(75),
#  'cash': np.int64(9),
#  'prize': np.int64(79),
#  'ten': np.int64(88),
#  'minut': np.int64(74),
#  'back': np.int64(6),
#  'offer': np.int64(76),
#  'talk': np.int64(87),
#  'later': np.int64(67),
#  'file': np.int64(44),
#  'contact': np.int64(21),
#  'us': np.int64(96),
#  'know': np.int64(66),
#  'activ': np.int64(1),
#  'join': np.int64(65),
#  'lucki': np.int64(71),
#  'draw': np.int64(36),
#  'everyth': np.int64(41),
#  'fine': np.int64(45),
#  'import': np.int64(62),
#  'updat': np.int64(95),
#  'okay': np.int64(77),
#  'soon': np.int64(86),
#  'email': np.int64(39),
#  'expir': np.int64(43),
#  'continu': np.int64(22),
#  'discount': np.int64(33),
#  'voucher': np.int64(98),
#  'earn': np.int64(38),
#  'come': np.int64(17),
#  'detect': np.int64(29),
#  'differ': np.int64(31),
#  'devic': np.int64(30),
#  'holiday': np.int64(58),
#  'cost': np.int64(23),
#  'five': np.int64(47),
#  'complet': np.int64(19),
#  'health': np.int64(56),
#  'done': np.int64(35),
#  'deactiv': np.int64(26),
#  'avail': np.int64(5),
#  'grab': np.int64(53),
#  'detail': np.int64(28),
#  'collect': np.int64(16)}

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=100,binary=True,ngram_range=(1,3))
X=cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'messag': np.int64(52),
#  'today': np.int64(75),
#  'congratul': np.int64(30),
#  'dollar': np.int64(33),
#  'gift': np.int64(41),
#  'card': np.int64(22),
#  'click': np.int64(29),
#  'claim': np.int64(27),
#  'meet': np.int64(51),
#  'tonight': np.int64(77),
#  'account': np.int64(0),
#  'verifi': np.int64(80),
#  'immedi': np.int64(43),
#  'verifi immedi': np.int64(81),
#  'account compromis verifi': np.int64(1),
#  'call': np.int64(21),
#  'reach': np.int64(59),
#  'home': np.int64(42),
#  'get': np.int64(40),
#  'loan': np.int64(49),
#  'appli': np.int64(16),
#  'send': np.int64(66),
#  'assign': np.int64(18),
#  'pleas': np.int64(57),
#  'select': np.int64(64),
#  'free': np.int64(39),
#  'let': np.int64(46),
#  'tomorrow': np.int64(76),
#  'win': np.int64(83),
#  'answer': np.int64(14),
#  'win brand': np.int64(84),
#  'answer three': np.int64(15),
#  'win brand new': np.int64(85),
#  'reward': np.int64(61),
#  'act': np.int64(8),
#  'claim free': np.int64(28),
#  'forget': np.int64(38),
#  'chosen': np.int64(26),
#  'credit': np.int64(31),
#  'check': np.int64(25),
#  'thank': np.int64(72),
#  'ticket': np.int64(73),
#  'win ticket': np.int64(86),
#  'win ticket bahama': np.int64(87),
#  'approv': np.int64(17),
#  'see': np.int64(62),
#  'exclus': np.int64(35),
#  'limit': np.int64(47),
#  'time': np.int64(74),
#  'limit time': np.int64(48),
#  'repli': np.int64(60),
#  'ye': np.int64(98),
#  'work': np.int64(94),
#  'work tonight': np.int64(95),
#  'number': np.int64(54),
#  'cash': np.int64(23),
#  'prize': np.int64(58),
#  'cash prize': np.int64(24),
#  'ten': np.int64(70),
#  'minut': np.int64(53),
#  'ten minut': np.int64(71),
#  'back': np.int64(20),
#  'offer': np.int64(55),
#  'talk': np.int64(68),
#  'later': np.int64(45),
#  'talk later': np.int64(69),
#  'file': np.int64(37),
#  'us': np.int64(79),
#  'activ': np.int64(9),
#  'activ free': np.int64(12),
#  'activ free membership': np.int64(13),
#  'winner': np.int64(88),
#  'lucki': np.int64(50),
#  'winner select': np.int64(89),
#  'winner select lucki': np.int64(90),
#  'woke': np.int64(91),
#  'woke plan': np.int64(92),
#  'woke plan today': np.int64(93),
#  'import': np.int64(44),
#  'updat': np.int64(78),
#  'account need': np.int64(4),
#  'account need verif': np.int64(5),
#  'okay': np.int64(56),
#  'soon': np.int64(67),
#  'see soon': np.int64(63),
#  'select exclus': np.int64(65),
#  'exclus offer': np.int64(36),
#  'email': np.int64(34),
#  'worth': np.int64(96),
#  'worth dollar': np.int64(97),
#  'discount': np.int64(32),
#  'voucher': np.int64(82),
#  'account login': np.int64(2),
#  'account login detect': np.int64(3),
#  'zero': np.int64(99),
#  'activ cancel': np.int64(10),
#  'activ cancel anytim': np.int64(11),
#  'avail': np.int64(19),
#  'account suspend': np.int64(6),
#  'account suspend hour': np.int64(7)}
