# %% [markdown]
# ## N-Grams Implementation

# %%
import pandas as pd
messages=pd.read_csv('spamCollection.csv',
                    sep='\t',names=["label","message"])

# %%
messages
# Out:
#                                                 label  message
# 0                                       label,message      NaN
# 1             ham,Hey there! How are you doing today?      NaN
# 2   spam,Congratulations! You've won a $1000 Walma...      NaN
# 3        ham,Are we still meeting for dinner tonight?      NaN
# 4   spam,URGENT! Your account has been compromised...      NaN
# 5                ham,I'll call you once I reach home.      NaN
# 6   spam,Get cheap loans with low interest now. Ap...      NaN
# 7    ham,Can you send me the assignment notes please?      NaN
# 8   spam,You have been selected for a free vacatio...      NaN
# 9            ham,Let's catch up tomorrow after class.      NaN
# 10  spam,Win a brand new iPhone just by answering ...      NaN
# 11    ham,Happy birthday! Hope you have a great day 🎉      NaN
# 12  spam,This is your last chance to claim your fr...      NaN
# 13  ham,Don't forget to bring your notebook tomorrow.      NaN
# 14  spam,You’ve been chosen to receive a complimen...      NaN
# 15                  ham,Thanks for your help earlier!      NaN
# 16  spam,Free entry in 2 a weekly competition to w...      NaN
# 17        ham,Can we reschedule our meeting for 4 pm?      NaN
# 18  spam,You are pre-approved for a credit card. A...      NaN
# 19                  ham,Good night, see you tomorrow!      NaN
# 20  spam,Exclusive deal: 70% off on all items. Lim...      NaN

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=100,binary=True)

# %%
cv.vocabulary_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 cv.vocabulary_
#
# AttributeError: 'CountVectorizer' object has no attribute 'vocabulary_'

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=100,binary=True,ngram_range=(2,3))
X=cv.fit_transform(corpus).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 from sklearn.feature_extraction.text import CountVectorizer
#       2 cv=CountVectorizer(max_features=100,binary=True,ngram_range=(2,3))
# ----> 3 X=cv.fit_transform(corpus).toarray()
#
# File c:\Users\hp\ML_Basics\venv\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\hp\ML_Basics\venv\Lib\site-packages\sklearn\feature_extraction\text.py:1377, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1369             warnings.warn(
#    1370                 "Upper case characters found in"
#    1371                 " vocabulary while 'lowercase'"
#    1372                 " is True. These entries will not"
#    1373                 " be matched with any documents"
#    1374             )
#    1375             break
# -> 1377 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1379 if self.binary:
#    1380     X.data.fill(1)
#
# File c:\Users\hp\ML_Basics\venv\Lib\site-packages\sklearn\feature_extraction\text.py:1283, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1281     vocabulary = dict(vocabulary)
#    1282     if not vocabulary:
# -> 1283         raise ValueError(
#    1284             "empty vocabulary; perhaps the documents only contain stop words"
#    1285         )
#    1287 if indptr[-1] > np.iinfo(np.int32).max:  # = 2**31 - 1
#    1288     if _IS_32BIT:
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words
